# %% [markdown]
# <center><img src="./img/redpopcorn.jpg"></center>

# %% [markdown]
# # Introduccion
#
# **¡Netflix!** Lo que comenzó en 1997 como un servicio de alquiler de DVD se ha convertido desde entonces en una de las empresas de medios y entretenimiento más grandes.
#
# Dada la gran cantidad de películas y series disponibles en la plataforma, es una oportunidad perfecta para ejercitar sus habilidades de análisis de datos exploratorios y sumergirse en la industria del entretenimiento.
#
# Trabajas para una productora especializada en estilos nostálgicos. Quieres investigar un poco sobre las películas estrenadas en la década de 1990. ¡Profundizará en los datos de Netflix y realizará análisis de datos exploratorios para comprender mejor esta increíble década cinematográfica!
#
# Se le ha proporcionado el conjunto de datos `netflix_data.csv`, junto con la siguiente tabla que detalla los nombres y descripciones de las columnas. ¡Siéntete libre de experimentar más con los datos como lo veas adecuado!

# %% [markdown]
# # Los Datos
# ## **netflix_data.csv**
# | Columna        | Descripción                       |
# |----------------|-----------------------------------|
# | `show_id`      | El ID del programa                |
# | `type`         | Tipo de programa                  |
# | `title`        | Título del programa               |
# | `director`     | Director del programa             |
# | `cast`         | Reparto del programa              |
# | `country`      | País de origen                    |
# | `date_added`   | Fecha de adición a Netflix        |
# | `release_year` | Año de lanzamiento en Netflix     |
# | `duration`     | Duración del programa en minutos  |
# | `description`  | Descripción del programa          |
# | `genre`        | Género del programa               |

# %% [markdown]
# # Instrucciones
#
# ¿Cuál fue la duración de una película más frecuente en la década de 1990? Guarde una respuesta aproximada como un número entero llamado **duration**.
#
# Una película se considera corta si tiene una duración inferior a 90 minutos. Cuente el número de cortometrajes de acción estrenados en la década de 1990 y guarde este número entero como **short_movie_count**.
#
# ¡Siéntete libre de experimentar con los datos!

# %% [markdown]
# # Ejecucion

# %% [markdown]
# ## Importar librerias y cargar datos

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Mostrar las primeras 5 filas
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %% [markdown]
# ## Datos de la decada de 1990

# %%
# Filtrar los datos de Netflix en la década de 1990
netflix_1990 = netflix_df[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] < 2000)]
netflix_1990
# Out:
#      show_id   type                            title            director  \
# 6         s8  Movie                              187      Kevin Reynolds
# 118     s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 145     s211  Movie           A Night at the Roxbury    John Fortenberry
# 167     s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 194     s274  Movie                     Aashik Awara         Umesh Mehra
# ...      ...    ...                              ...                 ...
# 4672   s7536  Movie                      West Beirut        Ziad Doueiri
# 4689   s7571  Movie      What's Eating Gilbert Grape     Lasse Hallström
# 4718   s7624  Movie                   Wild Wild West    Barry Sonnenfeld
# 4746   s7682  Movie                       Wyatt Earp     Lawrence Kasdan
# 4756   s7695  Movie                      Yaar Gaddar         Umesh Mehra
#
#                                                    cast        country  \
# ...

# %% [markdown]
# ## Encontrar las peliculas con mayor duracion

# %%
# Variable con la duracion mas frecuente
duration = netflix_1990['duration'].mode()[0] # Se usa el metodo estadistico moda
print(f'La duracion mas comun fue: {duration} min')
# Out:
# La duracion mas comun fue: 94 min

# %%
# Establecer un histograma de la duracion
plt.figure(figsize=(10, 6))
plt.hist(netflix_1990['duration'], bins=20)
plt.title('Distribución de las Duraciones de Películas en la Década de 1990')
plt.xlabel('Duración (minutos)')
plt.ylabel('Frecuencia')
plt.axvline(duration, color='r', linestyle='dashed', linewidth=1)
plt.text(duration + 5, plt.ylim()[1] * 0.9, f'Moda: {duration} min', color='r')
plt.show()

# %% [markdown]
# ## Subdataset peliculas de accion mas cortas

# %%
# Estableciendo el filtrado de peliculas de accion mas cortas
action_movies_shorts =  netflix_1990[(netflix_1990['genre'] == 'Action') & (netflix_1990['duration'] < 90)]
action_movies_shorts.head()
# Out:
#      show_id   type                      title      director  \
# 1288   s2039  Movie  EVANGELION: DEATH (TRUE)²  Hideaki Anno
# 1698   s2708  Movie                       Hero    Corey Yuen
# 2328   s3718  Movie          Look Out, Officer    Sze Yu Lau
# 2993   s4787  Movie               Passenger 57   Kevin Hooks
# 3297   s5299  Movie        Rumble in the Bronx  Stanley Tong
#
#                                                    cast        country  \
# 1288  Megumi Ogata, Kotono Mitsuishi, Megumi Hayashi...          Japan
# 1698  Takeshi Kaneshiro, Yuen Biao, Valerie Chow, Je...      Hong Kong
# 2328  Stephen Chow, Bill Tung, Stanley Sui-Fan Fung,...      Hong Kong
# 2993  Wesley Snipes, Bruce Payne, Tom Sizemore, Alex...  United States
# 3297  Jackie Chan, Anita Mui, Françoise Yip, Bill Tu...      Hong Kong
#
#             date_added  release_year  duration  \
# 1288     June 21, 2019          1998        69
# 1698    August 1, 2018          1997        89
# ...

# %% [markdown]
# ## Conteo de las peliculas de accion mas cortas

# %%
# Conteo de peliculas de accion cortas
short_movie_count = len(action_movies_shorts)
print(short_movie_count)
# Out:
# 7

# %% [markdown]
# **Hasta aqui tenemos los principales objetivos que fueron:**
#
# 1. Filtrado de peliculas de la decada de 1990
# 2. Variable con la mayor duracion en minutos en la decada de 1990
# 3. Conteo de las peliculas de accion mas corta a lo largo de 1990
#
# **Sientete libre de explorar los datos y aprender mas!!**
